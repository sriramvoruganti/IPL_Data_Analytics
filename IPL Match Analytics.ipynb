# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\sriram\Downloads\matches.csv")
df
# Out:
#       id  season           city       date                        team1  \
# 0      1    2017      Hyderabad   4/5/2017          Sunrisers Hyderabad
# 1      2    2017           Pune   4/6/2017               Mumbai Indians
# 2      3    2017         Rajkot   4/7/2017                Gujarat Lions
# 3      4    2017         Indore   4/8/2017       Rising Pune Supergiant
# 4      5    2017      Bangalore   4/8/2017  Royal Challengers Bangalore
# 5      6    2017      Hyderabad   4/9/2017                Gujarat Lions
# 6      7    2017         Mumbai   4/9/2017        Kolkata Knight Riders
# 7      8    2017         Indore  4/10/2017  Royal Challengers Bangalore
# 8      9    2017           Pune  4/11/2017             Delhi Daredevils
# 9     10    2017         Mumbai  4/12/2017          Sunrisers Hyderabad
# 10    11    2017        Kolkata  4/13/2017              Kings XI Punjab
# 11    12    2017      Bangalore  4/14/2017  Royal Challengers Bangalore
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              1
# umpire2              1
# umpire3            636
# dtype: int64

# %%
df.shape
# Out:
# (636, 18)

# %%
df.drop(['umpire3'], axis=1, inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
Teams ={'Royal Challengers Bangalore': 'RCB', 'Sunrisers Hyderabad':'SRH',
        'Mumbai Indians' : 'MI', 'Kolkata Knight Riders': 'KKR', 'Gujarat Lions': 'GL', 'Kings XI Punjab':'KXIP',
       'Delhi Daredevils' : 'DD', 'Chennai Super Kings' : 'CSK', 'Rajasthan Royals': 'RR',
       'Deccan Chargers' : 'DC', 'Kochi Tuskers Kerala' :'KCK', 'Pune Warriors':'PWI',
       'Rising Pune Supergiants': 'RPS'
    
    
        }

# %%
df['team1']= df['team1'].map(Teams)
df['team2']= df['team2'].map(Teams)

# %%
df.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   NaN       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   NaN  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied                       winner  win_by_runs  \
# 0         field  normal           0          Sunrisers Hyderabad           35
# 1         field  normal           0       Rising Pune Supergiant            0
# 2         field  normal           0        Kolkata Knight Riders            0
# 3         field  normal           0              Kings XI Punjab            0
# 4           bat  normal           0  Royal Challengers Bangalore           15
#
# ...

# %%
df.shape[0] #no of matches played
# Out:
# 636

# %%
len(df['city'].unique()) #various cities venues
# Out:
# 31

# %%
len(df['team1'].unique())
# Out:
# 14

# %%
erp = df['player_of_match'].value_counts()
erp
# Out:
# CH Gayle           18
# YK Pathan          16
# DA Warner          15
# AB de Villiers     15
# RG Sharma          14
# SK Raina           14
# MS Dhoni           13
# G Gambhir          13
# AM Rahane          12
# MEK Hussey         12
# DR Smith           11
# V Kohli            11
# V Sehwag           11
# SR Watson          10
# JH Kallis          10
# A Mishra            9
# SE Marsh            9
# KA Pollard          9
# SR Tendulkar        8
# AT Rayudu           7
# RV Uthappa          7
# AC Gilchrist        7
# RA Jadeja           7
# Harbhajan Singh     6
# BJ Hodge            6
# AD Russell          6
# UT Yadav            6
# M Vijay             6
# SP Narine           6
# A Nehra             6
#                    ..
# KV Sharma           1
# P Parameswaran      1
# Shoaib Akhtar       1
# RA Tripathi         1
# NV Ojha             1
# M Kartik            1
# PD Collingwood      1
# A Chandila          1
# Z Khan              1
# MN Samuels          1
# ...

# %%
erp.sort_values(ascending = False)[:10].plot(kind = 'bar')

# %%
filter = df['win_by_runs'].max() #victory by most no of runs
df[df['win_by_runs']==filter]
# Out:
#     id  season   city      date team1 team2       toss_winner toss_decision  \
# 43  44    2017  Delhi  5/6/2017    MI    DD  Delhi Daredevils         field
#
#     result  dl_applied          winner  win_by_runs  win_by_wickets  \
# 43  normal           0  Mumbai Indians          146               0
#
#    player_of_match             venue      umpire1    umpire2
# 43     LMP Simmons  Feroz Shah Kotla  Nitin Menon  CK Nandan

# %%
#victory based on wickets
filter1 = df['win_by_wickets'].max()
df[df['win_by_wickets']==filter1]
# Out:
#       id  season        city       date team1 team2  \
# 2      3    2017      Rajkot   4/7/2017    GL   KKR
# 34    35    2017  Chandigarh  4/30/2017    DD  KXIP
# 71    72    2008      Mumbai  4/27/2008    MI    DC
# 119  120    2009   Cape Town  4/19/2009  KXIP    DD
# 183  184    2010   Bangalore  3/18/2010    RR   RCB
# 298  299    2011      Mumbai  5/20/2011    MI    RR
# 376  377    2012      Jaipur  5/20/2012    RR    MI
# 390  391    2013  Chandigarh  4/10/2013  KXIP   CSK
# 542  543    2015       Delhi  4/26/2015    DD   RCB
# 590  591    2016      Rajkot  4/21/2016    GL   SRH
#
#                      toss_winner toss_decision  result  dl_applied  \
# 2          Kolkata Knight Riders         field  normal           0
# 34               Kings XI Punjab         field  normal           0
# 71               Deccan Chargers         field  normal           0
# 119             Delhi Daredevils         field  normal           1
# ...

# %%
# Analyzing the toss decisions (Batting/Fielding)

# %%
sns.countplot(x='season',hue='toss_decision',data=df,edgecolor=sns.color_palette("dark", 3))

# %%
#Let's furthur analyze on the toss winners

# %%
df['toss_winner'].value_counts().plot(kind='bar')

# %%
#BY THE GRAPH WE CAN EASILY INFER THAT MUMBAI INDIANS LEAD THE CHART
#ALTHOUGH RISING PUNE SUPERGIANTS IS IN THE LEAST, WE CAN TELL THAT
#RAJASTHAN ROYALS ENDS UP ON THE LOSING SIDE OF THE TOSS

# %%
teams = (df['team1'].value_counts() + df['team2'].value_counts()).reset_index()
teams.columns = ['team_name' , 'Matches_played']
teams
# Out:
#    team_name  Matches_played
# 0        CSK             131
# 1         DC              75
# 2         DD             147
# 3         GL              30
# 4        KCK              14
# 5        KKR             148
# 6       KXIP             148
# 7         MI             157
# 8        PWI              46
# 9        RCB             152
# 10       RPS              14
# 11        RR             118
# 12       SRH              76

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 92
# Chennai Super Kings            79
# Kolkata Knight Riders          77
# Royal Challengers Bangalore    73
# Kings XI Punjab                70
# Rajasthan Royals               63
# Delhi Daredevils               62
# Sunrisers Hyderabad            42
# Deccan Chargers                29
# Gujarat Lions                  13
# Pune Warriors                  12
# Rising Pune Supergiant         10
# Kochi Tuskers Kerala            6
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
sns.countplot(df['season']) #analyzing the various matches which take place

# %%
###BASED on this 2013 HAS CONDUCTED THE HIFHEST NO. OF MATCHES

# %%
df.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   NaN       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   NaN  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied winner  win_by_runs  win_by_wickets  \
# 0         field  normal           0    NaN           35               0
# 1         field  normal           0    NaN            0               7
# 2         field  normal           0    NaN            0              10
# 3         field  normal           0    NaN            0               6
# 4           bat  normal           0    NaN           15               0
#
# ...
