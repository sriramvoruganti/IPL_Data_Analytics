# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\sriram\Downloads\deliveries.csv")

# %%
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
filt = df['batsman'] =='DA Warner' ## here we filter the batsmen , and obtain DA warner

# %%
df_warner = df[filt] # we pass the dataframe of filt , which DA warner is present

# %%
df_warner.shape
# Out:
# (2902, 21)

# %%
df_warner
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 8              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 9              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 10             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 11             1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1328           6       2  Sunrisers Hyderabad                Gujarat Lions
# 1329           6       2  Sunrisers Hyderabad                Gujarat Lions
# ...

# %%
df_warner['dismissal_kind'].value_counts()
# Out:
# caught               62
# bowled               21
# run out               8
# stumped               4
# lbw                   4
# caught and bowled     2
# hit wicket            1
# Name: dismissal_kind, dtype: int64

# %%
df_warner['dismissal_kind'].value_counts().plot.pie() #dismissals

# %%
len(df_warner[df_warner['batsman_runs'] == 4])
# Out:
# 401

# %%
len(df_warner[df_warner['batsman_runs'] == 6])
# Out:
# 160

# %%
def count(df,runs):
    return len(df_warner[df_warner['batsman_runs'] ==runs])*runs

# %%
count(df_warner,1) ###runs scored by david warner as singles
# Out:
# 997

# %%
count(df_warner,2) #runs scored by david warner as doubles
# Out:
# 414

# %%
count(df_warner,3)
# Out:
# 39

# %%
count(df_warner,4)
# Out:
# 1604

# %%
count(df_warner,6)
# Out:
# 960

# %%
 slices = [997,414,39,1604,960]
labels = [1,2,3,4,6]
plt.pie(slices,labels=labels , autopct = '%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x186d73a1978>,
# ...
#  [Text(0.7817643705069365, 0.7738504177203069, '1'),
#   Text(-0.33959111687520577, 1.0462685474291247, '2'),
#   Text(-0.6816960876596443, 0.863302058418451, '3'),
#   Text(-1.0200956448131961, -0.4115882352948756, '4'),
#   Text(0.8038429148449225, -0.750890516822272, '6')],
#  [Text(0.4264169293674199, 0.4221002278474401, '24.8%'),
#   Text(-0.18523151829556675, 0.5706919349613407, '10.3%'),
#   Text(-0.3718342296325332, 0.4708920318646096, '1.0%'),
#   Text(-0.5564158062617433, -0.22450267379720487, '40.0%'),
#   Text(0.4384597717335941, -0.4095766455394211, '23.9%')])

# %%
# we analyzed that david warner scores roughly 40% of his runs by scoring 4s

# %%
df['bowling_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiant', 'Mumbai Indians',
#        'Kolkata Knight Riders', 'Gujarat Lions', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Deccan Chargers', 'Kochi Tuskers Kerala', 'Pune Warriors',
#        'Rising Pune Supergiants'], dtype=object)

# %%
Teams ={'Royal Challengers Bangalore': 'RCB', 'Sunrisers Hyderabad':'SRH',
        'Mumbai Indians' : 'MI', 'Kolkata Knight Riders': 'KKR', 'Gujarat Lions': 'GL', 'Kings XI Punjab':'KXIP',
       'Delhi Daredevils' : 'DD', 'Chennai Super Kings' : 'CSK', 'Rajasthan Royals': 'RR',
       'Deccan Chargers' : 'DC', 'Kochi Tuskers Kerala' :'KCK', 'Pune Warriors':'PWI',
       'Rising Pune Supergiants': 'RPS'
    
    
        }

# %%
df['batting_team'] = df['batting_team'].map(Teams)
df['bowling_team'] = df['bowling_team'].map(Teams)

# %%
df.head()
# Out:
#    match_id  inning batting_team bowling_team  over  ball    batsman  \
# 0         1       1          SRH          RCB     1     1  DA Warner
# 1         1       1          SRH          RCB     1     2  DA Warner
# 2         1       1          SRH          RCB     1     3  DA Warner
# 3         1       1          SRH          RCB     1     4  DA Warner
# 4         1       1          SRH          RCB     1     5  DA Warner
#
#   non_striker    bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 0    S Dhawan  TS Mills              0  ...         0            0
# 1    S Dhawan  TS Mills              0  ...         0            0
# 2    S Dhawan  TS Mills              0  ...         0            0
# 3    S Dhawan  TS Mills              0  ...         0            0
# 4    S Dhawan  TS Mills              0  ...         0            0
#
#    noball_runs  penalty_runs  batsman_runs  extra_runs  total_runs  \
# 0            0             0             0           0           0
# ...

# %%
#We have done the aliasing of the teams

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df.groupby(['match_id' , 'inning','batting_team'])['total_runs'].sum()
# Out:
# match_id  inning  batting_team
# 1         1       SRH             207
#           2       RCB             172
# 2         1       MI              184
# 3         1       GL              183
#           2       KKR             184
# 4         2       KXIP            164
# 5         1       RCB             157
#           2       DD              142
# 6         1       GL              135
#           2       SRH             140
# 7         1       KKR             178
#           2       MI              180
# 8         1       RCB             148
#           2       KXIP            150
# 9         1       DD              205
# 10        1       SRH             158
#           2       MI              159
# 11        1       KXIP            170
#           2       KKR             171
# 12        1       RCB             142
#           2       MI              145
# 13        2       GL              172
# 14        1       KKR             172
#           2       SRH             155
# ...

# %%
df.groupby(['match_id' , 'inning','batting_team'])['total_runs'].sum().reset_index()
# Out:
#       match_id  inning batting_team  total_runs
# 0            1       1          SRH         207
# 1            1       2          RCB         172
# 2            2       1           MI         184
# 3            3       1           GL         183
# 4            3       2          KKR         184
# 5            4       2         KXIP         164
# 6            5       1          RCB         157
# 7            5       2           DD         142
# 8            6       1           GL         135
# 9            6       2          SRH         140
# 10           7       1          KKR         178
# 11           7       2           MI         180
# 12           8       1          RCB         148
# 13           8       2         KXIP         150
# 14           9       1           DD         205
# 15          10       1          SRH         158
# 16          10       2           MI         159
# 17          11       1         KXIP         170
# 18          11       2          KKR         171
# ...

# %%
runs =df.groupby(['match_id' , 'inning','batting_team'])['total_runs'].sum().reset_index()
runs.drop('match_id' , axis=1 , inplace = True)
runs
# Out:
#       inning batting_team  total_runs
# 0          1          SRH         207
# 1          2          RCB         172
# 2          1           MI         184
# 3          1           GL         183
# 4          2          KKR         184
# 5          2         KXIP         164
# 6          1          RCB         157
# 7          2           DD         142
# 8          1           GL         135
# 9          2          SRH         140
# 10         1          KKR         178
# 11         2           MI         180
# 12         1          RCB         148
# 13         2         KXIP         150
# 14         1           DD         205
# 15         1          SRH         158
# 16         2           MI         159
# 17         1         KXIP         170
# 18         2          KKR         171
# 19         1          RCB         142
# 20         2           MI         145
# 21         2           GL         172
# 22         1          KKR         172
# 23         2          SRH         155
# ...

# %%
inning1 = runs[runs['inning']==1]
inning2 = runs[runs['inning']==2]

# %%
sns.boxplot(x = 'batting_team', y='total_runs', data = inning1)

# %%
sns.boxplot(x = 'batting_team', y='total_runs', data = inning2)

# %%
high_scores =  df.groupby(['match_id','inning','batting_team','bowling_team'])['total_runs'].sum().reset_index()
high_scores
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 1            1       2          RCB          SRH         172
# 2            3       1           GL          KKR         183
# 3            3       2          KKR           GL         184
# 4            5       1          RCB           DD         157
# 5            5       2           DD          RCB         142
# 6            6       1           GL          SRH         135
# 7            6       2          SRH           GL         140
# 8            7       1          KKR           MI         178
# 9            7       2           MI          KKR         180
# 10           8       1          RCB         KXIP         148
# 11           8       2         KXIP          RCB         150
# 12          10       1          SRH           MI         158
# 13          10       2           MI          SRH         159
# ...

# %%
score_200 = high_scores[high_scores['total_runs']>=200]
score_200
# Out:
#       match_id  inning batting_team bowling_team  total_runs
# 0            1       1          SRH          RCB         207
# 28          20       1          RCB           GL         213
# 46          32       1          SRH         KXIP         207
# 54          36       1          SRH          KKR         209
# 60          41       1           GL           DD         208
# 61          41       2           DD           GL         214
# 64          44       1           MI           DD         212
# 76          50       1         KXIP           MI         230
# 77          50       2           MI         KXIP         223
# 88          60       1          KKR          RCB         222
# 90          61       1          CSK         KXIP         240
# 91          61       2         KXIP          CSK         207
# 102         67       1          CSK           MI         208
# 103         67       2           MI          CSK         202
# ...

# %%
sns.countplot(score_200['batting_team'])

# %%
sns.countplot(score_200['bowling_team'])

# %%
#Lets analyze the performance of various Batsmen

# %%
balls = df.groupby('batsman')['ball'].sum().reset_index()
balls
# Out:
#                   batsman   ball
# 0          A Ashish Reddy    720
# 1              A Chandila     23
# 2                A Chopra    273
# 3             A Choudhary     71
# 4              A Flintoff    203
# 5                A Kumble    192
# 6                A Mishra   1412
# 7                A Mithun     94
# 8                A Mukund     93
# 9                 A Nehra    267
# 10                A Singh     42
# 11              A Symonds   2823
# 12               A Uniyal     21
# 13                A Zampa     34
# 14            AA Bilakhia    320
# 15              AA Chavan     40
# 16        AA Jhunjhunwala    816
# 17              AA Noffke     43
# 18             AB Agarkar    624
# 19              AB Barath    160
# 20               AB Dinda    212
# 21            AB McDonald    357
# 22         AB de Villiers   8703
# 23            AC Blizzard    309
# 24           AC Gilchrist   5413
# 25              AC Thomas     70
# 26               AC Voges    507
# ...

# %%
four = df[df['batsman_runs']==4]
four
# Out:
#         match_id  inning batting_team bowling_team  over  ball        batsman  \
# 2              1       1          SRH          RCB     1     3      DA Warner
# 8              1       1          SRH          RCB     2     2      DA Warner
# 13             1       1          SRH          RCB     2     7   MC Henriques
# 30             1       1          SRH          RCB     5     5   MC Henriques
# 32             1       1          SRH          RCB     6     1       S Dhawan
# 33             1       1          SRH          RCB     6     2       S Dhawan
# 35             1       1          SRH          RCB     6     4       S Dhawan
# 36             1       1          SRH          RCB     6     5       S Dhawan
# 63             1       1          SRH          RCB    11     2       S Dhawan
# 72             1       1          SRH          RCB    12     5   Yuvraj Singh
# 74             1       1          SRH          RCB    13     1   Yuvraj Singh
# ...

# %%
runs_4 = four.groupby('batsman')['batsman_runs'].count().reset_index()

# %%
runs_4.columns = ['batsman','4s']

# %%
runs_4 # this table shows the number of fours hit by each batsman
# Out:
#               batsman   4s
# 0      A Ashish Reddy   16
# 1            A Chopra    7
# 2         A Choudhary    1
# 3          A Flintoff    5
# 4            A Kumble    3
# 5            A Mishra   27
# 6            A Mithun    4
# 7            A Mukund    1
# 8             A Nehra    3
# 9           A Symonds   74
# 10            A Zampa    1
# 11        AA Bilakhia    5
# 12          AA Chavan    2
# 13    AA Jhunjhunwala   19
# 14          AA Noffke    1
# 15         AB Agarkar   13
# 16          AB Barath    5
# 17           AB Dinda    2
# 18        AB McDonald    9
# 19     AB de Villiers  287
# 20        AC Blizzard   21
# 21       AC Gilchrist  239
# 22          AC Thomas    1
# 23           AC Voges   15
# 24     AD Mascarenhas    5
# 25         AD Mathews   44
# 26            AD Nath    1
# 27         AD Russell   48
# 28         AG Murtaza    1
# 29        AG Paunikar    9
# ..                ...  ...
# 338        TM Dilshan  140
# 339           TM Head   12
# ...

# %%
#similarly let's calculate the no of sixes

# %%
six = df[df['batsman_runs']==6]
six
# Out:
#         match_id  inning batting_team bowling_team  over  ball       batsman  \
# 10             1       1          SRH          RCB     2     4     DA Warner
# 47             1       1          SRH          RCB     8     4  MC Henriques
# 75             1       1          SRH          RCB    13     2  Yuvraj Singh
# 89             1       1          SRH          RCB    15     3  Yuvraj Singh
# 91             1       1          SRH          RCB    15     5  MC Henriques
# 105            1       1          SRH          RCB    18     1      DJ Hooda
# 115            1       1          SRH          RCB    19     3  Yuvraj Singh
# 121            1       1          SRH          RCB    20     3   BCJ Cutting
# 124            1       1          SRH          RCB    20     6   BCJ Cutting
# 142            1       2          RCB          SRH     3     6      CH Gayle
# 144            1       2          RCB          SRH     4     2      CH Gayle
# ...

# %%
runs_6 = six.groupby('batsman')['batsman_runs'].count().reset_index()

# %%
runs_6.columns = ['batsman','6s']

# %%
runs_6
# Out:
#              batsman   6s
# 0     A Ashish Reddy   15
# 1        A Choudhary    1
# 2         A Flintoff    2
# 3           A Mishra    5
# 4           A Mithun    1
# 5            A Nehra    1
# 6          A Symonds   41
# 7    AA Jhunjhunwala    5
# 8         AB Agarkar    5
# 9          AB Barath    1
# 10       AB McDonald    4
# 11    AB de Villiers  158
# 12       AC Blizzard    2
# 13      AC Gilchrist   92
# 14         AC Thomas    1
# 15          AC Voges    3
# 16    AD Mascarenhas    1
# 17        AD Mathews   29
# 18        AD Russell   37
# 19          AJ Finch   59
# 20            AJ Tye    3
# 21        AL Menaria   18
# 22          AM Nayar   20
# 23         AM Rahane   60
# 24          AN Ahmed    1
# 25           AP Dole    1
# 26       AP Majumdar    2
# 27           AP Tare   11
# 28          AR Patel   28
# 29           AS Raut    7
# ..               ...  ...
# 271      Sunny Singh    1
# 272      T Henderson    1
# 273          T Kohli    1
# ...

# %%
player = pd.concat([runs,balls.iloc[:,1],runs_4.iloc[:,1]],axis=1)
player
# Out:
#       inning batting_team  total_runs    ball     4s
# 0          1          SRH         207   720.0   16.0
# 1          2          RCB         172    23.0    7.0
# 2          1           MI         184   273.0    1.0
# 3          1           GL         183    71.0    5.0
# 4          2          KKR         184   203.0    3.0
# 5          2         KXIP         164   192.0   27.0
# 6          1          RCB         157  1412.0    4.0
# 7          2           DD         142    94.0    1.0
# 8          1           GL         135    93.0    3.0
# 9          2          SRH         140   267.0   74.0
# 10         1          KKR         178    42.0    1.0
# 11         2           MI         180  2823.0    5.0
# 12         1          RCB         148    21.0    2.0
# 13         2         KXIP         150    34.0   19.0
# 14         1           DD         205   320.0    1.0
# 15         1          SRH         158    40.0   13.0
# 16         2           MI         159   816.0    5.0
# ...

# %%
player.fillna(0,inplace = True)

# %%
player
# Out:
#       inning batting_team  total_runs    ball     4s
# 0          1          SRH         207   720.0   16.0
# 1          2          RCB         172    23.0    7.0
# 2          1           MI         184   273.0    1.0
# 3          1           GL         183    71.0    5.0
# 4          2          KKR         184   203.0    3.0
# 5          2         KXIP         164   192.0   27.0
# 6          1          RCB         157  1412.0    4.0
# 7          2           DD         142    94.0    1.0
# 8          1           GL         135    93.0    3.0
# 9          2          SRH         140   267.0   74.0
# 10         1          KKR         178    42.0    1.0
# 11         2           MI         180  2823.0    5.0
# 12         1          RCB         148    21.0    2.0
# 13         2         KXIP         150    34.0   19.0
# 14         1           DD         205   320.0    1.0
# 15         1          SRH         158    40.0   13.0
# 16         2           MI         159   816.0    5.0
# ...

# %%
#strike Rate

# %%
player['strike rate'] = (player['total_runs']/player['ball']) *100

# %%
player
# Out:
#       inning batting_team  total_runs    ball     4s  strike rate
# 0          1          SRH         207   720.0   16.0    28.750000
# 1          2          RCB         172    23.0    7.0   747.826087
# 2          1           MI         184   273.0    1.0    67.399267
# 3          1           GL         183    71.0    5.0   257.746479
# 4          2          KKR         184   203.0    3.0    90.640394
# 5          2         KXIP         164   192.0   27.0    85.416667
# 6          1          RCB         157  1412.0    4.0    11.118980
# 7          2           DD         142    94.0    1.0   151.063830
# 8          1           GL         135    93.0    3.0   145.161290
# 9          2          SRH         140   267.0   74.0    52.434457
# 10         1          KKR         178    42.0    1.0   423.809524
# 11         2           MI         180  2823.0    5.0     6.376196
# 12         1          RCB         148    21.0    2.0   704.761905
# ...

# %%
grp = df.groupby(['match_id','batsman','batting_team'])['batsman_runs'].sum().reset_index()

# %%
grp
# Out:
#       match_id         batsman batting_team  batsman_runs
# 0            1     A Choudhary          RCB             6
# 1            1     BCJ Cutting          SRH            16
# 2            1        CH Gayle          RCB            32
# 3            1       DA Warner          SRH            14
# 4            1        DJ Hooda          SRH            16
# 5            1       KM Jadhav          RCB            31
# 6            1    MC Henriques          SRH            52
# 7            1   Mandeep Singh          RCB            24
# 8            1       S Aravind          RCB             0
# 9            1        S Dhawan          SRH            40
# 10           1       SR Watson          RCB            22
# 11           1       STR Binny          RCB            11
# 12           1     Sachin Baby          RCB             1
# 13           1         TM Head          RCB            30
# 14           1        TS Mills          RCB             6
# ...

# %%
max_runs_scores = grp.groupby('batsman')['batsman_runs'].max().reset_index()
max_runs_scores.columns = ['batsman','max_runs']

# %%
max_runs_scores
# Out:
#                   batsman  max_runs
# 0          A Ashish Reddy        36
# 1              A Chandila         4
# 2                A Chopra        24
# 3             A Choudhary        15
# 4              A Flintoff        24
# 5                A Kumble         8
# 6                A Mishra        31
# 7                A Mithun        11
# 8                A Mukund        19
# 9                 A Nehra        22
# 10                A Singh         1
# 11              A Symonds       117
# 12               A Uniyal         4
# 13                A Zampa         0
# 14            AA Bilakhia        22
# 15              AA Chavan         7
# 16        AA Jhunjhunwala        53
# 17              AA Noffke         9
# 18             AB Agarkar        39
# 19              AB Barath        33
# 20               AB Dinda         6
# 21            AB McDonald        33
# 22         AB de Villiers       133
# 23            AC Blizzard        51
# 24           AC Gilchrist       109
# ...

# %%
#TOP 10 run scorers , across all seasons

# %%
max_runs =df.groupby('batsman')['batsman_runs'].sum()
max_runs.sort_values(ascending = False)[:10].plot(kind = 'bar')

# %%
#top team scores

# %%
df.groupby(['match_id' , 'inning','batting_team'])['batsman_runs'].sum().reset_index().sort_values(by = 'batsman_runs',ascending = False).head(10)
# Out:
#       match_id  inning batting_team  batsman_runs
# 813        411       1          RCB           252
# 1234       620       1          RCB           244
# 400        206       1          CSK           240
# 106         61       1          CSK           234
# 1118       562       1          RCB           228
# 965        486       1         KXIP           221
# 88          50       1         KXIP           220
# 1154       580       1          RCB           220
# 747        380       1          CSK           216
# 178         97       1         KXIP           216

# %%
df['dismissal_kind'].unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
dismissal_kind = [ 'caught', 'bowled', 'lbw', 'caught and bowled',
       'stumped', 'hit wicket']

# %%
hwt = df[df['dismissal_kind'].isin(dismissal_kinds)]
hwt.head()
# Out:
#      match_id  inning batting_team bowling_team  over  ball        batsman  \
# 11          1       1          SRH          RCB     2     5      DA Warner
# 64          1       1          SRH          RCB    11     3       S Dhawan
# 94          1       1          SRH          RCB    16     2   MC Henriques
# 116         1       1          SRH          RCB    19     4   Yuvraj Singh
# 160         1       2          RCB          SRH     6     4  Mandeep Singh
#
#       non_striker       bowler  is_super_over  ...  bye_runs  legbye_runs  \
# 11       S Dhawan  A Choudhary              0  ...         0            0
# 64   MC Henriques    STR Binny              0  ...         0            0
# 94   Yuvraj Singh    YS Chahal              0  ...         0            0
# 116      DJ Hooda     TS Mills              0  ...         0            0
# 160      CH Gayle  Rashid Khan              0  ...         0            0
#
# ...

# %%
#top 10 bowlers

# %%
hwt['bowler'].value_counts()[:10].plot(kind = 'bar')
